# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishaan178/Ishaan1598/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program for wheather prediction
def weather_prediction(t, h, w):
    result = (0.5 * t**2 - 0.2 * h - 15) / 0.9
    result = round(result)

    print("\nWeather Prediction Calculation:")
    print(f"Temperature (t) = {t}°C")
    print(f"Humidity (h) = {h}%")
    print(f"Wind Speed (w) = {w} m/s (Note: this is not used directly in the formula but included in the inputs)")
    print("\nUsing the formula:")
    print("w = (0.5 * t^2 - 0.2 * h - 15) / 0.9")

    print(f"\nCalculated Weather Prediction (w) = {result}")

    if result > 40:
        weather_condition = "Sunny"
    elif 20 <= result <= 40:
        weather_condition = "Partly Cloudy"
    elif 0 <= result < 20:
        weather_condition = "Cloudy"
    elif result < 0:
        weather_condition = "Rainy"

    print(f"Weather Condition: {weather_condition}")


temperature = float(input("Enter the temperature (°C): "))
humidity = float(input("Enter the humidity (%): "))
wind_speed = float(input("Enter the wind speed (m/s): "))

weather_prediction(temperature, humidity, wind_speed)
# Out:
# Enter the temperature (°C): 40
# Enter the humidity (%): 20
# Enter the wind speed (m/s): 5
#
# Weather Prediction Calculation:
# Temperature (t) = 40.0°C
# Humidity (h) = 20.0%
# Wind Speed (w) = 5.0 m/s (Note: this is not used directly in the formula but included in the inputs)
#
# Using the formula:
# w = (0.5 * t^2 - 0.2 * h - 15) / 0.9
#
# Calculated Weather Prediction (w) = 868
# Weather Condition: Sunny
